# %%
from dotenv import load_dotenv
load_dotenv()

import sys
sys.path.append('./src')
import os
from Spot import Spot 

print(os.getenv('redirectURI'))
spot = Spot()
# Out:
# http://localhost:8889/callback

# %%
spot.get_liked_songs()
# Out:
# Pre-process Liked Songs: 1815
# ['7xpUt2HacitDSOhdtPAcdy',
#  '4Wos0h9ECU2Z3oJMTQxpbc',
#  '0whmIaItqkT8e5PVuPyhvT',
#  '2EtZFeLn9msgg4qJzT9Vql',
#  '4LKYOetuIF5c9XjeLBL9av',
#  '4ZPdLEztrlZqbJkgHNw54L',
#  '1BxfuPKGuaTgP7aM0Bbdwr',
#  '3tiMYOhaYuDEOwHXZW8DWm',
#  '7gb39FeCydnNWREnqs6guo',
#  '4V0x90QcMh4ZxwHzEWOdtK',
#  '358bOvBiZCS9fRzNYosw6c',
#  '1lNqQ3ss5PVfu4HbvBhxCN',
#  '3WSOUb3U7tqURbBSgZTrZX',
#  '4jDf2BYKBzUkpoc3pvNIfP',
#  '0GjEhVFGZW8afUYGChu3Rr',
#  '03v70ZBxmcPX3RWAZMzqaW',
#  '13FHy6nHjXHbzHj1dZFB1G',
#  '3IqwOIVNLdBs7av6n8Plrt',
#  '5lUTzPuiloBHm1qEaJcJfF',
#  '5L95vS64rG1YMIFm1hLjyZ',
#  '0HYxvIjWvX8Mcjx5ShhB9l',
#  '5B4UpK5ajp6bCoiYgArfwB',
#  '6NQbvueqSRWgHOailFx7th',
#  '7GYwQpHMMh6aJhpsjVGjC2',
#  '7kDhGzc1hgkQQyzpvBmKcX',
#  '2RK1IiAjWdl6VQYsCKf3k9',
#  '7gaA3wERFkFkgivjwbSvkG',
#  '1hLUl3qUqiB3qtHln01mah',
#  '4zN21mbAuaD0WqtmaTZZeP',
#  '4udjo5nLK61pKajakfrndc',
#  '0cVaY6PNGxCPi1gOIapr26',
#  '3DBYMf7Di5gsAEEOKjnEm3',
#  '30fQvBnDR8jLdN0SFcsFos',
# ...
